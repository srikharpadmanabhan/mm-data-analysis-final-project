# %%
import pandas as pd
import pickle

# %%
conference_stats_df = pd.read_csv("MM Data/Conference Stats.csv")

# %%
conference_stats_df.head()
# Out:
#    YEAR  CONF ID  CONF  BADJ EM  BADJ O  BADJ D  BARTHAG    G    W    L  ...  \
# 0  2024        1   A10      5.6   108.1   102.5    0.648  481  272  209  ...
# 1  2024        2   ACC     12.0   111.7    99.7    0.787  492  282  210  ...
# 2  2024        3    AE     -5.2   101.4   106.6    0.360  270  133  137  ...
# 3  2024        4  Amer      4.2   108.2   104.0    0.612  442  237  205  ...
# 4  2024        5  ASun     -7.9   103.8   111.7    0.301  355  153  202  ...
#
#    AVG HGT  EFF HGT    EXP  TALENT   FT%  OP FT%   PPPO   PPPD  ELITE SOS  \
# 0   77.133   80.264  1.884  18.386  72.2    71.8  1.067  1.035     18.353
# 1   77.897   81.078  1.653  62.324  73.8    73.1  1.083  1.037     27.996
# 2   76.776   79.091  2.147   6.236  71.3    71.2  1.020  1.034     11.337
# 3   77.293   80.347  2.237  30.455  72.0    71.6  1.077  1.054     17.309
# 4   76.777   79.668  2.026   8.164  73.1    72.5  1.069  1.114     11.659
#
#     WAB
# 0  -5.8
# 1  -2.0
# 2 -10.4
# 3  -7.0
# 4 -12.0
#
# [5 rows x 45 columns]

# %%
from Conference import Conference


IGNORE_FIELDS_FOR_CONFERENCE_STATS = ["YEAR","CONF ID","CONF","W", "L"]

# create overall conference dictionary 
conference_data_dict = dict()



# Iterate through df, and create the conferences from the Conferences.py file ignoring the fields above
for _, row in conference_stats_df.iterrows():
    row = row.to_dict()
    
    # Get the right fields for the stats, ignoring the id variables above
    curr_conference_stats = {
        ("CONFERENCE " + k): v for k, v in row.items() if k not in IGNORE_FIELDS_FOR_CONFERENCE_STATS
    }
    
    conference_data_dict[(row["CONF"], row["YEAR"])] = Conference(conference_name=row["CONF"], conference_stats=curr_conference_stats)

    
# Dump data into pickle file
with open('pickle_files/conference-data.pkl', 'wb') as conference_file:
    pickle.dump(conference_data_dict, conference_file, protocol=pickle.HIGHEST_PROTOCOL)
    
print(list(conference_data_dict.items())[0])
print((list(conference_data_dict.items())[0])[1])
# Out:
# (('A10', 2024), <Conference.Conference object at 0x10e382ec0>)
# Conference(name='A10', stats={'CONFERENCE BADJ EM': 5.6, 'CONFERENCE BADJ O': 108.1, 'CONFERENCE BADJ D': 102.5, 'CONFERENCE BARTHAG': 0.648, 'CONFERENCE G': 481, 'CONFERENCE WIN%': 56.54885655, 'CONFERENCE EFG%': 51.3, 'CONFERENCE EFGD%': 49.3, 'CONFERENCE FTR': 33.6, 'CONFERENCE FTRD': 32.3, 'CONFERENCE TOV%': 16.7, 'CONFERENCE TOV%D': 16.8, 'CONFERENCE OREB%': 28.3, 'CONFERENCE DREB%': 71.7, 'CONFERENCE OP OREB%': 28.3, 'CONFERENCE OP DREB%': 71.7, 'CONFERENCE RAW T': 67.6, 'CONFERENCE 2PT%': 50.7, 'CONFERENCE 2PT%D': 48.5, 'CONFERENCE 3PT%': 34.9, 'CONFERENCE 3PT%D': 33.7, 'CONFERENCE BLK%': 10.7, 'CONFERENCE BLKED%': 10.2, 'CONFERENCE AST%': 52.9, 'CONFERENCE OP AST %': 51.6, 'CONFERENCE 2PTR': 60.2, 'CONFERENCE 3PTR': 39.8, 'CONFERENCE 2PTRD': 61.2, 'CONFERENCE 3PTRD': 38.8, 'CONFERENCE BADJ T': 68.0, 'CONFERENCE AVG HGT': 77.133, 'CONFERENCE EFF HGT': 80.264, 'CONFERENCE EXP': 1.884, 'CONFERENCE TALENT': 18.386, 'CONFERENCE FT%': 72.2, 'CONFERENCE OP FT%': 71.8, 'CONFERENCE PPPO': 1.067, 'CONFERENCE PPPD': 1.035, 'CONFERENCE ELITE SOS': 18.353, 'CONFERENCE WAB': -5.8})
